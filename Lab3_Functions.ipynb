# %%
# [CELL 1] STUDENT CONFIGURATION

LAST_NAME = "Vargas"
STUDENT_ID = "TUPM-25-0698"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Vargas
# Seed Digit: 8
# Digit Sum: 30
# Surname Length: 6

# %%
# [CELL 2] FUNCTIONAL ENCAPSULATION

def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# System Initialized for: Vargas
# ========================================
# Identity Code: 48

# %%
# [CELL 3] LEGB VALIDATION

gloabal_value = ID_SUM

def scope_test():
    gloabal_value = SEED_DIGIT
    print("Inside function:", gloabal_value)

scope_test()
print("Outside function:", gloabal_value)
# Out:
# Inside function: 8
# Outside function: 30

# %%
# [CELL 4] PARAMETRIC PROCESSING

def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round(average,2))

    for k,v in info.items():
        print(f"{k}: {v}")

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    surname=LAST_NAME
)
# Out:
# === Vargas Academic Report ===
# Scores: (80, 30, 30)
# Total: 140
# Average: 46.67
# id: TUPM-25-0698
# surname: Vargas

# %%
# [CELL 5] RETURN MECHANISM

def compute_area(radius):
    return 3.1416 * radius**2

area = compute_area(SEED_DIGIT + 2)
print("Computed Area:", round(area,2))
# Out:
# Computed Area: 314.16

# %%
# [CELL 6] SAFE CALCULATOR

def safe_calculator(x,y):
    try:
        result = x/y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculation Result:", safe_calculator(ID_SUM, SEED_DIGIT))
# Out:
# Calculation Result: 3.75

# %%
# [CELL 7] RECURSION

def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial Result:", factorial(SEED_DIGIT))
# Out:
# Factorial Result: 40320

# %%
# [CELL 8] STRING RECURSION

def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])

print("Reversed Surname:", reverse(LAST_NAME.upper()))
# Out:
# Reversed Surname: SAGRAV

# %%
# [CELL 9] DECORATOR

def logger(func):
    def wrapper(*args, **kwargs):
        print("Executing:", func._name_)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply(x, y):
    return x * y
    
print("MULTIPLICATION:", multiply(SEED_DIGIT, NAME_LENGTH))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 13
#       9 @logger
#      10 def multiply(x, y):
#      11     return x * y
# ---> 13 print("MULTIPLICATION:", multiply(SEED_DIGIT, NAME_LENGTH))
#
# Cell In[22], line 5, in logger.<locals>.wrapper(*args, **kwargs)
#       4 def wrapper(*args, **kwargs):
# ----> 5     print("Executing:", func._name_)
#       6     return func(*args, **kwargs)
#
# AttributeError: 'function' object has no attribute '_name_'
